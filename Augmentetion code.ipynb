# %%
pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import Augmentor

# %%
p = Augmentor.Pipeline(r"/content/drive/MyDrive/HappyMonk/Classification by CNN/train/banana")
# Out:
# Initialised with 75 image(s) found.
# Output directory set to /content/drive/MyDrive/HappyMonk/Classification by CNN/train/banana/output.

# %%
p.rotate(probability=1.0, max_left_rotation=5, max_right_rotation=10)

# %%
p.flip_top_bottom(probability=0.5)

# %%
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)

# %%
p.flip_left_right(probability=0.4)

# %%
p.shear(1,20,20)

# %%
p.random_distortion(1,8,8,8)

# %%
p.status()
# Out:
# Operations: 6
# 	0: RotateRange (probability=1.0 max_left_rotation=-5 max_right_rotation=10 )
# 	1: Flip (probability=0.5 top_bottom_left_right=TOP_BOTTOM )
# 	2: Zoom (probability=0.3 min_factor=1.1 max_factor=1.6 )
# 	3: Flip (probability=0.4 top_bottom_left_right=LEFT_RIGHT )
# 	4: Shear (probability=1 max_shear_left=20 max_shear_right=20 )
# 	5: Distort (probability=1 grid_width=8 grid_height=8 magnitude=8 randomise_magnitude=True )
# Images: 75
# Classes: 1
# 	Class index: 0 Class label: banana
# Dimensions: 62
# 	Width: 1903 Height: 2331
# 	Width: 736 Height: 1319
# 	Width: 770 Height: 1052
# 	Width: 995 Height: 615
# 	Width: 768 Height: 576
# 	Width: 1200 Height: 630
# 	Width: 1600 Height: 1067
# 	Width: 1035 Height: 630
# 	Width: 230 Height: 318
# 	Width: 1200 Height: 1600
# 	Width: 1200 Height: 1057
# 	Width: 1280 Height: 720
# 	Width: 2674 Height: 2641
# 	Width: 1725 Height: 3264
# 	Width: 768 Height: 1024
# 	Width: 4500 Height: 3243
# 	Width: 700 Height: 700
# ...

# %%
#p.remove_operation(2)

# %%
num_of_samples = 150
p.sample(num_of_samples)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=7360x4912 at 0x7F37A52910A0>: 100%|██████████| 150/150 [02:17<00:00,  1.09 Samples/s]
